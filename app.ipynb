# %%
from ultralytics import YOLO

model = YOLO("7_seg.pt")

print("\n🔎 Model Classes:\n")
for k, v in model.names.items():
    print(f"Class ID {k} → '{v}'")
# Out:
# 🔎 Model Classes:
#
# Class ID 0 → '0'
# Class ID 1 → '1'
# Class ID 2 → '10'
# Class ID 3 → '11'
# Class ID 4 → '12'
# Class ID 5 → '2'
# Class ID 6 → '3'
# Class ID 7 → '4'
# Class ID 8 → '5'
# Class ID 9 → '6'
# Class ID 10 → '7'
# Class ID 11 → '8'
# Class ID 12 → '9'
